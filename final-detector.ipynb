# %% [markdown]
# <a href="https://www.kaggle.com/code/aabhak02/final-detector?scriptVersionId=312677039" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import os

# ------------------------
# GPU check (no memory growth)
# ------------------------
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print("GPU ready:", gpus[0])
else:
    print("Using CPU")

# ------------------------
# Data pipeline
# ------------------------
train_dir = '/kaggle/input/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images/train'
test_dir  = '/kaggle/input/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images/test'

datagen = ImageDataGenerator(rescale=1./255)

train_gen = datagen.flow_from_directory(
    train_dir,
    target_size=(32,32),
    batch_size=32,
    class_mode='binary'
)

test_gen = datagen.flow_from_directory(
    test_dir,
    target_size=(32,32),
    batch_size=32,
    class_mode='binary',
    shuffle=False
)

# ------------------------
# Tiny CNN
# ------------------------
model = Sequential([
    Conv2D(16,(3,3),activation='relu',input_shape=(32,32,3)),
    MaxPooling2D(2,2),
    Conv2D(32,(3,3),activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(64,activation='relu'),
    Dropout(0.3),
    Dense(1,activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

# ------------------------
# Train
# ------------------------
model.fit(train_gen, validation_data=test_gen, epochs=5)

# ------------------------
# Predict
# ------------------------
preds = model.predict(test_gen)
print(preds[:10])

# ------------------------
# Save trained model
# ------------------------
MODEL_DIR = '/kaggle/working/models'
os.makedirs(MODEL_DIR, exist_ok=True)
MODEL_PATH = os.path.join(MODEL_DIR, 'my_model.h5')

model.save(MODEL_PATH)
print(f"Model saved at: {MODEL_PATH}")
# Out:
# 2026-04-18 18:47:21.412418: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776538041.595813      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776538041.646530      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776538042.067077      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import os
import csv
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# ------------------------
# Enable GPU
# ------------------------
import tensorflow as tf

print("GPUs available:", tf.config.list_physical_devices('GPU'))
# ------------------------
# Paths
# ------------------------
TEST_DIR = "/kaggle/input/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images/test/REAL"
MODEL_PATH = "/kaggle/input/models/aabhak02/mymodel-h5/keras/default/1/my_model.h5"

IMG_SIZE = (32, 32)
BATCH_SIZE = 128

# ------------------------
# Load model
# ------------------------
model = load_model(MODEL_PATH)

# ------------------------
# Collect images
# ------------------------
test_files = [
    f for f in os.listdir(TEST_DIR)
    if os.path.isfile(os.path.join(TEST_DIR, f))
]

print("Total images:", len(test_files))

# ------------------------
# Preprocess function
# ------------------------
def load_batch(files):
    batch = []
    for f in files:
        img_path = os.path.join(TEST_DIR, f)
        img = image.load_img(img_path, target_size=IMG_SIZE)
        img = image.img_to_array(img) / 255.0
        batch.append(img)
    return np.array(batch)

# ------------------------
# CSV output
# ------------------------
csv_path = "/kaggle/working/predictions_real.csv"

with open(csv_path, "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["image_name", "prediction", "probability"])

    # Process in batches
    for i in range(0, len(test_files), BATCH_SIZE):

        batch_files = test_files[i:i+BATCH_SIZE]
        batch_images = load_batch(batch_files)

        preds = model.predict(batch_images, verbose=0)

        for img_name, pred in zip(batch_files, preds):
            prob = float(pred[0])
            label = "REAL" if prob > 0.5 else "AI"

            writer.writerow([img_name, label, prob])

        print(f"Processed {min(i+BATCH_SIZE, len(test_files))}/{len(test_files)}")

print("CSV saved:", csv_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# GPUs available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Total images: 10000
# Processed 128/10000
# Processed 256/10000
# Processed 384/10000
# Processed 512/10000
# Processed 640/10000
# Processed 768/10000
# Processed 896/10000
# Processed 1024/10000
# Processed 1152/10000
# Processed 1280/10000
# Processed 1408/10000
# Processed 1536/10000
# Processed 1664/10000
# Processed 1792/10000
# Processed 1920/10000
# Processed 2048/10000
# Processed 2176/10000
# Processed 2304/10000
# Processed 2432/10000
# Processed 2560/10000
# Processed 2688/10000
# Processed 2816/10000
# Processed 2944/10000
# Processed 3072/10000
# Processed 3200/10000
# Processed 3328/10000
# Processed 3456/10000
# Processed 3584/10000
# Processed 3712/10000
# Processed 3840/10000
# Processed 3968/10000
# ...

# %%
import os
import csv
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# ------------------------
# Enable GPU

print("GPUs available:", tf.config.list_physical_devices('GPU'))

# ------------------------
# Paths
# ------------------------
TEST_DIR = "/kaggle/input/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images/test/FAKE"
MODEL_PATH = "/kaggle/input/models/aabhak02/mymodel-h5/keras/default/1/my_model.h5"

IMG_SIZE = (32, 32)
BATCH_SIZE = 128

# ------------------------
# Load model
# ------------------------
model = load_model(MODEL_PATH)

# ------------------------
# Collect images
# ------------------------
test_files = [
    f for f in os.listdir(TEST_DIR)
    if os.path.isfile(os.path.join(TEST_DIR, f))
]

print("Total images:", len(test_files))

# ------------------------
# Preprocess function
# ------------------------
def load_batch(files):
    batch = []
    for f in files:
        img_path = os.path.join(TEST_DIR, f)
        img = image.load_img(img_path, target_size=IMG_SIZE)
        img = image.img_to_array(img) / 255.0
        batch.append(img)
    return np.array(batch)

# ------------------------
# CSV output
# ------------------------
csv_path = "/kaggle/working/predictions_ai.csv"

with open(csv_path, "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["image_name", "prediction", "probability"])

    # Process in batches
    for i in range(0, len(test_files), BATCH_SIZE):

        batch_files = test_files[i:i+BATCH_SIZE]
        batch_images = load_batch(batch_files)

        preds = model.predict(batch_images, verbose=0)

        for img_name, pred in zip(batch_files, preds):
            prob = float(pred[0])
            label = "REAL" if prob > 0.5 else "AI"

            writer.writerow([img_name, label, prob])

        print(f"Processed {min(i+BATCH_SIZE, len(test_files))}/{len(test_files)}")

print("CSV saved:", csv_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# GPUs available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Total images: 10000
# Processed 128/10000
# Processed 256/10000
# Processed 384/10000
# Processed 512/10000
# Processed 640/10000
# Processed 768/10000
# Processed 896/10000
# Processed 1024/10000
# Processed 1152/10000
# Processed 1280/10000
# Processed 1408/10000
# Processed 1536/10000
# Processed 1664/10000
# Processed 1792/10000
# Processed 1920/10000
# Processed 2048/10000
# Processed 2176/10000
# Processed 2304/10000
# Processed 2432/10000
# Processed 2560/10000
# Processed 2688/10000
# Processed 2816/10000
# Processed 2944/10000
# Processed 3072/10000
# Processed 3200/10000
# Processed 3328/10000
# Processed 3456/10000
# Processed 3584/10000
# Processed 3712/10000
# Processed 3840/10000
# Processed 3968/10000
# ...

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# ------------------------
# Path and params
# ------------------------
TEST_DIR = "/kaggle/input/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images/test/FAKE"  # your folder here
IMG_SIZE = (32, 32)  # same as your CNN input

# ------------------------
# Load the saved model
# ------------------------
model = load_model('/kaggle/input/models/aabhak02/mymodel-h5/keras/default/1/my_model.h5')

# ------------------------
# Preprocess function
# ------------------------
def preprocess_img(img_path):
    img = image.load_img(img_path, target_size=IMG_SIZE)
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    return img_array

# ------------------------
# Predict all images in the folder
# ------------------------
test_files = [f for f in os.listdir(TEST_DIR) if os.path.isfile(os.path.join(TEST_DIR, f))]

for img_file in test_files:
    img_path = os.path.join(TEST_DIR, img_file)
    img_input = preprocess_img(img_path)
    pred = model.predict(img_input)[0][0]  # sigmoid output
    label = "REAL" if pred > 0.5 else "AI"
    print(f"{img_file}: {label} ({pred:.5f})")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# 943 (5).jpg: REAL (0.96633)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 534 (7).jpg: AI (0.00001)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 81 (2).jpg: AI (0.09282)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 869 (9).jpg: AI (0.20732)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 610 (10).jpg: AI (0.00077)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 623.jpg: AI (0.45220)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 697 (8).jpg: AI (0.04089)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 194 (4).jpg: AI (0.28234)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 435 (3).jpg: REAL (0.97613)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 380 (3).jpg: AI (0.33813)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 491 (8).jpg: AI (0.05006)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 680 (8).jpg: AI (0.04487)
# ...

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# ------------------------
# Path and params
# ------------------------
TEST_DIR = "/kaggle/input/datasets/birdy654/cifake-real-and-ai-generated-synthetic-images/test/REAL"  # your folder here
IMG_SIZE = (32, 32)  # same as your CNN input

# ------------------------
# Load the saved model
# ------------------------
model = load_model('/kaggle/input/models/aabhak02/mymodel-h5/keras/default/1/my_model.h5')

# ------------------------
# Preprocess function
# ------------------------
def preprocess_img(img_path):
    img = image.load_img(img_path, target_size=IMG_SIZE)
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    return img_array

# ------------------------
# Predict all images in the folder
# ------------------------
test_files = [f for f in os.listdir(TEST_DIR) if os.path.isfile(os.path.join(TEST_DIR, f))]

for img_file in test_files:
    img_path = os.path.join(TEST_DIR, img_file)
    img_input = preprocess_img(img_path)
    pred = model.predict(img_input)[0][0]  # sigmoid output
    label = "REAL" if pred > 0.5 else "AI"
    print(f"{img_file}: {label} ({pred:.5f})")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 0664.jpg: REAL (0.91878)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 0280 (6).jpg: REAL (0.63280)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 0816 (6).jpg: REAL (0.99932)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 0704 (5).jpg: REAL (0.99999)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 0896 (9).jpg: REAL (0.99957)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 0316 (3).jpg: REAL (0.99882)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 0102 (3).jpg: REAL (0.98441)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 0369 (4).jpg: REAL (0.99154)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 0010 (4).jpg: REAL (0.99891)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 0029 (10).jpg: AI (0.48608)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 0235 (4).jpg: REAL (0.99986)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# ...

# %%
import os

model_dir = '/kaggle/working/models'
os.makedirs(model_dir, exist_ok=True)  # creates folder if it doesn't exist
print("Folder ready:", model_dir)
# Out:
# Folder ready: /kaggle/working/models

# %%
print("Min:", preds.min())
print("Max:", preds.max())
print("Mean:", preds.mean())
# Out:
# Min: 4.17222e-05
# Max: 0.32913306
# Mean: 0.059897617

# %%
loss, acc = model.evaluate(test_gen)
print("Test accuracy:", acc)
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 84ms/step - accuracy: 0.8723 - loss: 0.3326
# Test accuracy: 0.910099983215332

# %%
preds = model.predict(test_gen)
labels = (preds > 0.5).astype(int)

print("Real predicted:", labels.sum())
print("AI predicted:", len(labels) - labels.sum())
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 26s 40ms/step
# Real predicted: 11066
# AI predicted: 8934

# %%
from sklearn.metrics import confusion_matrix, classification_report

preds = model.predict(test_gen)
labels = (preds > 0.5).astype(int)

print(confusion_matrix(test_gen.classes, labels))
print(classification_report(test_gen.classes, labels))
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 34ms/step
# [[8568 1432]
#  [ 366 9634]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91     10000
#            1       0.87      0.96      0.91     10000
#
#     accuracy                           0.91     20000
#    macro avg       0.91      0.91      0.91     20000
# weighted avg       0.91      0.91      0.91     20000

# %% [markdown]
# FINAL val_accuracy: 0.91

# %%
import os
os.listdir("/kaggle/working")
# Out:
# ['models', 'predictions_ai.csv', 'predictions_real.csv', '__notebook__.ipynb']

# %%
import pandas as pd

df = pd.read_csv("/kaggle/working/predictions_real.csv")
df.head()
# Out:
#      image_name prediction  probability
# 0      0664.jpg       REAL     0.918776
# 1  0280 (6).jpg       REAL     0.632799
# 2  0816 (6).jpg       REAL     0.999316
# 3  0704 (5).jpg       REAL     0.999994
# 4  0896 (9).jpg       REAL     0.999574

# %%
import pandas as pd

df = pd.read_csv("/kaggle/working/predictions_ai.csv")
df.head()
# Out:
#      image_name prediction  probability
# 0   943 (5).jpg       REAL     0.966334
# 1   534 (7).jpg         AI     0.000013
# 2    81 (2).jpg         AI     0.092819
# 3   869 (9).jpg         AI     0.207322
# 4  610 (10).jpg         AI     0.000765
